# %%
class Archivos_Xml:

    def __init__ (self, ruta_xml):
        self.ruta_xml = ruta_xml
    

    def apertura_xml (self):

        tree = ET.parse(self.ruta_xml)
        root = tree.getroot()

        xml_list = []
        for child in root:
            xml_dict = {}
            for subchild in child:
                xml_dict[subchild.tag] = subchild.text
            xml_list.append(xml_dict)

        return xml_list

    
    def limpieza_xml (self):

        tree = ET.parse(self.ruta_xml)
        root = tree.getroot()

        xml_list = []
        for child in root:
            xml_dict = {}
            for subchild in child:
                xml_dict[subchild.tag] = subchild.text
            xml_list.append(xml_dict)
        
        tuplas_xml = []

        for fila in xml_list:
    
            if fila ["gender"] == "0":
                fila["gender"] = "Man"

            elif fila["gender"] == "1":
                fila["gender"] = "Woman"

            elif fila["gender"] == "2":
                fila["gender"] = "Nonbinary"

            elif fila["gender"] == "3":
                fila["gender"] = "Prefer not to say"

            elif fila["gender"] == "4":                           
                fila["gender"] = "Prefer to self-describe"

            tuplas_xml.append(tuple(fila.values()))
        
        return tuplas_xml
    
    def crear_tabla(self, password,query):
        cnx = mysql.connector.connect(user='root', password = password,
                                auth_plugin='mysql_native_password',
                                host='127.0.0.1',
                                database = 'ADALAB_pro')
        sql = cnx.cursor()
    
        try:
            sql.execute(query)
            print(sql)
        except mysql.connector.Error as err:
            print(err)
            print("Error Code:", err.errno)
            print("SQLSTATE", err.sqlstate)
            print("Message", err.msg)

        
        cnx.close()
        
        

def creacion_tupla(self,archivo, query, val):


        archivo = Archivos_Xml.apertura_xml()
        
        lista_tupla = []
        
        for linea in archivo:
            lista_tupla.append(tuple(linea.split(";")))
                
            return lista_tupla
        
        cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
                                    host='127.0.0.1', database='ADALAB_pro')
        sql = cnx.cursor()
        
        
        try:
            sql.executemany(query, val)
            cnx.commit()
            print(sql.rowcount, "registro insertado.")
            
        except mysql.connector.Error as err:
            
            print(err)
            print("Error Code:", err.errno)
            print("SQLSTATE", err.sqlstate)
            print("Message", err.msg)
