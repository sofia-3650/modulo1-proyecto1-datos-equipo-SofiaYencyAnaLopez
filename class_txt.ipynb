# %%
class Archivos_Txt:

    def __init__ (self, ruta_txt):
        self.ruta_txt = ruta_txt

    
    def apertura_txt (self, archivo):

        with open(archivo,'r', encoding = "UTF-8") as file:
            contenido = file.read()

        return contenido
    

    def limpieza_txt (self, archivo):
  
        with open(archivo,'r') as file:
            file_source = file.read()
        
        archivo_limpio = []

        for elemento in file_source:
            limpieza = elemento.replace(" ", "").replace("\n", "").replace('<', "under"). replace("null", "NULL")
            limpieza = tuple(limpieza.split(";"))
            archivo_limpio.append(limpieza)
            
            
        return archivo_limpio


    def creacion_tablas_txt(self, password,query):
        cnx = mysql.connector.connect(user='root', password = password,
                                    auth_plugin='mysql_native_password',
                                    host='127.0.0.1',
                                    database = 'ADALAB_pro')
        sql = cnx.cursor()
    
        try:
            sql.execute(query)
            print(sql)

        except mysql.connector.Error as err:
            print(err)
            print("Error Code:", err.errno)
            print("SQLSTATE", err.sqlstate)
            print("Message", err.msg)

    
        cnx.close()
        
    
    def insercion_datos(self, archivo, query, val):


        archivo = Archivos_Txt.apertura_txt()
        
        lista_tupla = []
        
        for linea in archivo:
            lista_tupla.append(tuple(linea.split(";")))
                
            return lista_tupla
        
        cnx = mysql.connector.connect(user='root', password = "AlumnaAdalab",
                              auth_plugin='mysql_native_password',
                              host='127.0.0.1',
                              database = 'ADALAB_pro')
        sql = cnx.cursor()
        
        
        try:
            sql.executemany(query, val)
            cnx.commit()
            print(sql.rowcount, "registro insertado.")
            
        except mysql.connector.Error as err:
            
            print(err)
            print("Error Code:", err.errno)
            print("SQLSTATE", err.sqlstate)
            print("Message", err.msg)
